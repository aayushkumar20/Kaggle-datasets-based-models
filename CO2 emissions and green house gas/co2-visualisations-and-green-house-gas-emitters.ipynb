# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Importing all required modules.

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import scipy

# %% [markdown]
# ## Importing data from the given dataset.

# %%
df = pd.read_csv('/kaggle/input/global-co2-emissions/CO2Emission_LifeExp.csv')

# %%
df.head()

# %% [markdown]
# ## Checking for null values.

# %%
df.isnull().sum()

# %% [markdown]
# #### It shows that, there's no null value in the given dataset.

# %% [markdown]
# # Graphical representation. (group)

# %%
def feat_plot(feature):
    plt.figure(figsize=(16, 6))
    plt.subplot(1, 3, 1)
    feature.plot(kind = 'hist')
    plt.title(f'{feature.name} histogram plot')
    
    plt.subplot(1, 3, 2)
    mu, sigma = scipy.stats.norm.fit(feature)
    sns.distplot(feature) 
    plt.axvline(mu, linestyle = '--', color = 'green', )
    plt.axvline(sigma, linestyle = '--', color = 'red')
    plt.title(f'{feature.name} distribution plot')
    
    plt.subplot(1, 3, 3)
    sns.boxplot(feature)
    plt.title(f'{feature.name} box plot')
    plt.show()

# %%
num_feat = df.select_dtypes(exclude = 'object')

# %%
for i in num_feat.columns:
    feat_plot(num_feat[i])

# %% [markdown]
# # Listing all the columns name.

# %%
df.columns

# %%
df.shape

# %%
df[df.duplicated()].count()

# %% [markdown]
# #### There's no duplicate data in the dataset.

# %% [markdown]
# # Sorting data on the basis of CO2 emissions and Life Expectancy.

# %%
sort1 = df.sort_values('CO2Emissions',ascending=False)
sort1

# %%
sort2 = df.sort_values('LifeExpectancy',ascending=False)
sort2

# %%
sort3 = df.sort_values('Percapita',ascending=False)
sort3

# %%
sns.catplot(x="Country", y="Percapita", data=sort1.head(10),height=5, aspect=27/9,)

# %%
sns.catplot(x="Country", y="CO2Emissions", data=sort1.head(10),height=5, aspect=27/9,)

# %%
sns.catplot(x="Country", y="LifeExpectancy", data=sort1.head(10),height=5, aspect=27/9,)

# %% [markdown]
# ## Describing the dataset.

# %%
df.describe()

# %%
df.corr()

# %% [markdown]
# ## Making area relational graph models.

# %%
plt.plot(df.CO2Emissions, df.Percapita)

# %%
plt.plot(df.Population, df.YearlyChange)

# %%
ttest,pval = ttest_ind(df.LifeExpectancy,df.Percapita)
if pval <0.05:
  print("Null hypothesis")
else:
  print("not a null hypothesis")

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
model = ols('Percapita ~ LifeExpectancy', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table

# %% [markdown]
# # Thank you 😃.
